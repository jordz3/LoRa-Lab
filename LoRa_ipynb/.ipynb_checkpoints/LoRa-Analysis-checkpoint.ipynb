# %%
# !pip install haversine
# !pip install pandas

# %%
import sys
import datetime
import requests
import smtplib
import csv

import pandas as pd
import matplotlib.pyplot as plt

from weather_au import api
from IPython.display import IFrame
import haversine as hs
from haversine import Unit
#https://developers.google.com/maps/documentation/embed/embedding-map#choosing_map_modes
#https://developers.google.com/maps/documentation/embed/get-started

# %%
#read csv from here and take experimental data

import pandas as pd
df = pd.read_csv ('~\Documents\Arduino\MPE LoRa\Log_Files\Test.csv',sep=',')

df
# Out:
#        Time  Number      S_Lat      S_Long  Bandwidth  CodingRate  Frequency  \
# 0   7:57:30       1 -31.707623  115.793190     500000           5  915000000
# 1   7:57:48       2 -31.707628  115.793198     500000           5  915000000
# 2   7:57:50       3 -31.707647  115.793221     500000           5  915000000
# 3   7:57:52       4 -31.707632  115.793228     500000           5  915000000
# 4   7:57:58      19 -31.708961  115.792656     500000           5  915000000
# 5   7:58:27      23 -31.709429  115.791618     500000           5  915000000
# 6   7:58:29      24 -31.709459  115.791336     500000           5  915000000
# 7   7:58:34      26 -31.709372  115.790649     500000           5  915000000
# 8   7:58:36      27 -31.709343  115.790428     500000           5  915000000
# 9   7:58:40      30 -31.709227  115.789963     500000           5  915000000
# 10  7:58:45      32 -31.709270  115.789268     500000           5  915000000
# ...

# %%
df["R_Lat"][4]
# Out:
# -31.708042

# %%
ts = pd.Series(df['TxPower'])
ts.plot();

# %%
ts = pd.Series(df['PacketRSSI'])
ts.plot();

# %%
ts = pd.Series(df['RSSI'])
ts.plot();

# %%
ts = pd.Series(df['SNR'], index=df['Number'])
ts.plot();

# %%
now = datetime.datetime.now()
time_string = now.strftime("%Y-%m-%d %H:%M:%S")
print(time_string)
# Out:
# 2021-09-07 16:21:26

# %%
api_file = open("api-key.txt", "r")
api_key = api_file.read()
api_file.close()

# %%
receiver_lat = float(df["R_Lat"][0])
receiver_long = float(df["R_Long"][0])
receiver = str(receiver_lat) + "," + str(receiver_long)
print("Receiver:\t"+receiver)

sender_lat = float(df["S_Lat"][0])
sender_long =  float(df["S_Long"][0])
sender = str(sender_lat) + "," + str(sender_long)
print("Sender:\t\t"+sender)


center_lat = (receiver_lat+sender_lat)/2
center_long = (receiver_long+sender_long)/2
center = str(center_lat) + "," + str(center_long)
print("center:\t\t"+center)
# Out:
# Receiver:	-31.708047999999998,115.788574
# Sender:		-31.707622999999998,115.79319
# center:		-31.707835499999998,115.790882

# %%
embed = "https://www.google.com/maps/embed/v1/directions?key="+api_key+"&origin="+receiver+"&destination="+sender+"&mode=flying&center="+center+"&zoom=16"
print(embed)
# Out:
# https://www.google.com/maps/embed/v1/directions?key=AIzaSyC0mtqOnhuGx3W6t6Oky-WtTIFng4zvRlE&origin=-31.708047999999998,115.788574&destination=-31.707622999999998,115.79319&mode=flying&center=-31.707835499999998,115.790882&zoom=16

# %%
IFrame(embed, width=600, height=600)
# Out:
#         <iframe
#             width="600"
#             height="600"
#             src="https://www.google.com/maps/embed/v1/directions?key=AIzaSyC0mtqOnhuGx3W6t6Oky-WtTIFng4zvRlE&origin=-31.708047999999998,115.788574&destination=-31.707622999999998,115.79319&mode=flying&center=-31.707835499999998,115.790882&zoom=16"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#[plot more map points instead of one
# heat map of signal strength
# scatter plot of x and y
# colours for signal strength


loc1 = (receiver_lat,receiver_long)
loc2 = (sender_lat,sender_long)

distance = round(hs.haversine(loc1,loc2,unit=Unit.METERS),2)
print("Distance between Sender and Receiver: "+str(distance)+ " Metres")
# Out:
# Distance between Sender and Receiver: 439.21 Metres

# %%
w = api.WeatherApi(search='perth+wa', debug=0)

location = w.location()
# check if the search produced a result (other methods will also return None if the search fails).
if location is None:
    sys.exit('Search failed for location ' + loc)

print(f"\nLocation: {location['name']} {location['state']}, timezone:{location['timezone']}\n")
# Out:
# Location: East Perth WA, timezone:Australia/Perth

# %%
for warn in w.warnings():
    print(f"Warning short title:  {warn['short_title']}")

    warning = w.warning(id=warn['id'])
    print(f"Warning title:        {warning['title']}")

# %%
observations = w.observations()
print(f"\nObservations (temp): {observations['temp']:2}")
print(f"\nObservations (humidity): {observations['humidity']:2}")
# Out:
# Observations (temp): 26.6
#
# Observations (humidity): 20

# %%
print('\n3 Hourly:')
print('Note: Observations are from most recent to least. API is currently incorrect\n')

for f in w.forecasts_3hourly():
    print(f"{f['time']} temp:{f['temp']:2}, {f['icon_descriptor']}")
# Out:
# 3 Hourly:
# Note: Observations are from most recent to least. API is currently incorrect
#
# 2021-09-07T09:00:00Z temp:24, sunny
# 2021-09-07T12:00:00Z temp:18, sunny
# 2021-09-07T15:00:00Z temp:15, mostly_sunny
# 2021-09-07T18:00:00Z temp:11, mostly_sunny
# 2021-09-07T21:00:00Z temp:10, mostly_sunny
# 2021-09-08T00:00:00Z temp:13, mostly_sunny
# 2021-09-08T03:00:00Z temp:24, mostly_sunny
# 2021-09-08T06:00:00Z temp:25, mostly_sunny
# 2021-09-08T09:00:00Z temp:22, shower
# 2021-09-08T12:00:00Z temp:18, shower
# 2021-09-08T15:00:00Z temp:17, shower
# 2021-09-08T18:00:00Z temp:16, rain
# 2021-09-08T21:00:00Z temp:14, rain
# 2021-09-09T00:00:00Z temp:15, rain
# 2021-09-09T03:00:00Z temp:22, rain
# 2021-09-09T06:00:00Z temp:22, rain

# %%
#steps for student using html outline given
#short description on suing ttgo software and jupyter notebook
#jupyter notebook online experiment if not installed on pc already


#how easily to use - encounter problems with setup - would you be able to modify and build on this
#what would you like them to learn
    #settings in lora affect 
    #practical undedrstanding of lora settings and environments on wireless transmissions
    #choosing an appropriate lora setting  for a particular environment
        #disadvantages and overcoming circumstances
#Survey
#how much data was gathered, quality of it - implement into notebook 

#Potential future experiments and building on?

#implement form in teams with question list
    #Atif to implement

    
#getting data with Rachel
    #familiarise with hardware/software
    #potentially Atif as well
    #first guinea pig
    
    
    
    
#before and after test
    #during lecture?
    #after lab
    
#my experiments
    #description of ttgo lora
    #description of jupyter notebook analyser
    #standardised IOT testbed
    
    
    

# Dummy run to check everything is working prior to 

# make a separate repository for the lab

# remove simulations,

# run experiments that students would want to run, share with class
# - upload their results to github repository

# - what was the worst case scenario that you cam across
# what did you learn from LoRa

# feedback
# - on code, instructions
# - what would make it easier to use for teaching and use case
# - how to improve ths system


# forms on lab

# make th public github for labs
# share public to Atif

# %%
#
